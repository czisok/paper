# %%
import pickle
import sys
sys.path.append('/data/CaoZhong/utils/')
from my_utils import *

# %%
with open('result/train_info_month10-11-12_subset2_grid', 'rb') as f:
    loss_list = pickle.load(f)
    auc_list = pickle.load(f)
    legend_list = pickle.load(f)

# %%
semilogy_mul('step', 'loss', [list(range(len(loss_list[0])))]*len(loss_list), loss_list, legend_list)
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
semilogy_mul('step', 'auc', [list(range(len(loss_list[0])))]*len(auc_list), auc_list, legend_list)
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>
