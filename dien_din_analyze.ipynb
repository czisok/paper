# %%
import pickle
import sys
sys.path.append('/data/CaoZhong/utils/')
from my_utils import *

# %%
loss_list, auc_list, acc_list, legend = [], [], [], []

# %% [markdown]
# # base dien

# %%
with open('dien-gluon/dien_base_loss_auc_acc.pkl', 'rb') as f:
    loss_list.append(pickle.load(f))
    auc_list.append(pickle.load(f))
    acc_list.append(pickle.load(f))
    legend.append(pickle.load(f))

# %% [markdown]
# # base din

# %%
with open('DIN-gluon/base_model/base_din_loss_auc_acc.pkl', 'rb') as f:
    loss_list.append(pickle.load(f))
    auc_list.append(pickle.load(f))
    acc_list.append(pickle.load(f))
    legend.append(pickle.load(f))

# %% [markdown]
# # rnn din

# %%
with open('DIN-gluon/rnn/rnn_din_loss_auc_acc.pkl', 'rb') as f:
    loss_list.append(pickle.load(f))
    auc_list.append(pickle.load(f))
    acc_list.append(pickle.load(f))
    legend.append(pickle.load(f))

# %% [markdown]
# # attention din

# %%
with open('DIN-gluon/din/attention_din_loss_auc_acc.pkl', 'rb') as f:
    loss_list.append(pickle.load(f))
    auc_list.append(pickle.load(f))
    acc_list.append(pickle.load(f))
    legend.append(pickle.load(f))

# %% [markdown]
# # 对比分析

# %%
semilogy_mul('step', 'loss',[list(range(len(loss_list[0])))]*len(loss_list), loss_list, legend)
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
semilogy_mul('step', 'auc',[list(range(len(auc_list[0])))]*len(auc_list), auc_list, legend)
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
semilogy_mul('step', 'acc',[list(range(len(acc_list[0])))]*len(acc_list), acc_list, legend)
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>
