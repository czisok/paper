# %%
import pickle
import sys
sys.path.append('/data/CaoZhong/utils/')
from my_utils import *

# %% [markdown]
# # tf 对比gluon

# %% [markdown]
# ## 子数据集对比

# %%
with open('DIN-master/base_model/din_basemodel_train_result_tf_sub.pkl', 'rb') as f:
    loss_tf_sub = pickle.load(f)
    auc_tf_sub = pickle.load(f)

# %%
with open('DIN-gluon/base_model/din_basemodel_train_result_gluon_sub.pkl', 'rb') as f:
    loss_gluon_sub = pickle.load(f)
    auc_gluon_sub = pickle.load(f)

# %%
max(auc_tf_sub),max(auc_gluon_sub)
# Out:
# (0.8429747594040091, 0.83837883711261374)

# %%
semilogy_mul('step', 'loss', [list(range(len(loss_tf_sub)))]*2, [loss_tf_sub, loss_gluon_sub], legend=['tf', 'gluon'])
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
semilogy_mul('step', 'loss', [list(range(len(auc_tf_sub)))]*2, [auc_tf_sub, auc_gluon_sub], legend=['tf', 'gluon'])
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## 全量数据

# %%
with open('DIN-master/base_model/din_basemodel_train_result_tf.pkl', 'rb') as f:
    loss_tf = pickle.load(f)
    auc_tf = pickle.load(f)

# %%
with open('DIN-gluon/base_model/din_basemodel_train_result_gluon.pkl', 'rb') as f:
    loss_gluon = pickle.load(f)
    auc_gluon = pickle.load(f)

# %%
max(auc_tf),max(auc_gluon)
# Out:
# (0.8637850331512135, 0.85523314102919512)

# %%
len(loss_tf), len(loss_gluon)
# Out:
# (815, 815)

# %%
semilogy_mul('step', 'loss', [list(range(len(loss_tf)))]*2, [loss_tf, loss_gluon], legend=['tf', 'gluon'])
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
semilogy_mul('step', 'loss', [list(range(len(auc_tf)))]*2, [auc_tf, auc_gluon], legend=['tf', 'gluon'])
# Out:
# <module 'matplotlib.pyplot' from '/data/CaoZhong/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
max(auc_tf[400:]),max(auc_gluon[400:])
# Out:
# (0.8637850331512135, 0.849730955693623)
